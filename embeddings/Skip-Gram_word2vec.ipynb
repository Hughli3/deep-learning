# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random 

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
# for word , count in word_counts.items():
#     count/total_count
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
# 如果p_drop大于随机数就丢它，小于就留下
# 去除那些出现次数特别多但没意义的词

# %%
type(train_words)
# Out:
# list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # words 是长单词列表 idx是单词在列表中的位置
    # Your code here
    # 我们会随机选择一个范围在0-C之间的数R
    R = np.random.randint(1, window_size+1)
    # 在这里抓取R个词
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])

    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')
    # 为了让batch可以动态调整大小所以留为None

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))  # create embedding weight matrix here
    # 返回大小的随机数矩阵，服从正态分布 此处的形状为(n_vocab,n_embedding)
    # -1， 1是分布范围
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory `checkpoints': File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6946 0.1952 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6217 0.1929 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5326 0.1922 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6206 0.1919 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5590 0.1920 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5564 0.1918 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5391 0.1914 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5376 0.1915 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4962 0.1919 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4292 0.1921 sec/batch
# Nearest to they: messier, tyrrhenian, ibero, mcqueen, sextilis, marathon, thawed, forgot,
# Nearest to by: manned, zircon, cadences, reestablishment, hosts, places, kooning, euphrates,
# Nearest to that: independents, encke, flintoff, conducts, montevideo, protectionism, audacity, howerd,
# Nearest to a: concerts, endothermy, restriction, sanders, antibiotics, guelleh, aerosols, oppenheim,
# Nearest to th: house, outlines, uninterested, galore, consultancy, posteriori, welcome, satire,
# Nearest to he: heresies, cxd, overridden, tsiolkovsky, armpit, expansions, extroverted, apologise,
# Nearest to as: flannel, catechisms, selene, tact, unanimous, echomail, debra, bighead,
# Nearest to also: creighton, intensities, behaviorism, vanity, guarded, igor, puritanical, luxuries,
# Nearest to engine: oaths, suburbs, pcm, felt, ngel, rin, siculus, paltrow,
# Nearest to brother: preparatory, plesiosaur, veered, dollywood, noble, narses, macedonians, deception,
# Nearest to square: phasing, overtime, heenan, burnet, belleville, advent, benefiting, walls,
# Nearest to operations: pillow, piping, suppression, analyse, lya, pollutants, thackeray, pretensions,
# Nearest to road: galatea, unter, imo, domes, burrows, sgt, mandinka, newsreader,
# Nearest to san: thereupon, adverbs, bhaktivedanta, storefront, starling, endorsing, defences, tek,
# Nearest to experience: jellinek, legally, rory, gregg, hastings, massacres, glc, vulgate,
# Nearest to mathematics: mercury, vacuum, magistracy, zetalisp, wrongly, cameos, tallies, notary,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4728 0.1943 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3727 0.1955 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3238 0.1937 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2656 0.1925 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1847 0.1925 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1606 0.1930 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1095 0.1924 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0786 0.1929 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0036 0.1927 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0129 0.1951 sec/batch
# Nearest to they: messier, tyrrhenian, mcqueen, forgot, additional, resisted, thawed, straight,
# Nearest to by: places, hosts, manned, in, coup, cadences, householder, keep,
# Nearest to that: independents, encke, variety, maybe, covenant, conducts, declining, protectionism,
# Nearest to a: once, concerts, restriction, sanders, tallest, material, per, written,
# Nearest to th: house, outlines, welcome, costs, posteriori, satire, run, uninterested,
# Nearest to he: heresies, cxd, responsibilities, expansions, overridden, v, childhood, tsiolkovsky,
# Nearest to as: flannel, unanimous, set, usual, public, tact, capacities, selene,
# Nearest to also: using, creighton, intensities, behaviorism, guarded, closed, vanity, igor,
# Nearest to engine: oaths, scale, suburbs, shocked, felt, particularly, pcm, siculus,
# Nearest to brother: preparatory, noble, plesiosaur, dollywood, veered, deception, scattering, revolutionize,
# Nearest to square: overtime, walls, advent, magazine, ordered, phasing, voucher, pathologists,
# Nearest to operations: pillow, piping, suppression, paul, adolph, thackeray, older, fee,
# Nearest to road: galatea, domes, unter, power, sgt, systems, burrows, overcoming,
# Nearest to san: adverbs, eight, thereupon, molars, compilers, storefront, defences, leave,
# Nearest to experience: legally, jellinek, rory, gregg, exile, massacres, vehicles, hastings,
# Nearest to mathematics: vacuum, mercury, inquiry, confesses, shivers, booking, content, operates,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9420 0.1957 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9177 0.1931 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8687 0.1934 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8808 0.1938 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8102 0.1928 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8394 0.1938 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8185 0.1939 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8052 0.1933 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7788 0.1936 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7886 0.1940 sec/batch
# Nearest to they: tyrrhenian, messier, mcqueen, marathon, thawed, additional, forgot, resisted,
# Nearest to by: places, hosts, manned, imposition, cease, coup, in, habsburg,
# Nearest to that: conducts, independents, maybe, encke, protectionism, covenant, runs, archaeologists,
# Nearest to a: restriction, once, concerts, material, sanders, tallest, endothermy, guelleh,
# Nearest to th: house, posteriori, outlines, uninterested, welcome, depends, debate, happiest,
# Nearest to he: heresies, cxd, boogie, semitic, neolithic, v, tramiel, nepal,
# Nearest to as: flannel, tact, selene, unanimous, usual, set, catechisms, environmentalism,
# Nearest to also: behaviorism, guarded, creighton, using, igor, intensities, usgs, luxuries,
# Nearest to engine: oaths, suburbs, shocked, scale, felt, particularly, siculus, typography,
# Nearest to brother: preparatory, noble, deception, plesiosaur, dollywood, unforeseen, veered, alarming,
# Nearest to square: overtime, walls, voucher, advent, phasing, applications, identity, filmmakers,
# Nearest to operations: pillow, suppression, piping, paul, thackeray, fee, funded, adolph,
# Nearest to road: galatea, unter, domes, power, sgt, overcoming, systems, gordon,
# Nearest to san: eight, adverbs, thereupon, selling, molars, storefront, executive, defences,
# Nearest to experience: legally, jellinek, exile, hastings, rory, gregg, massacres, vehicles,
# Nearest to mathematics: mercury, vacuum, wrongly, booking, inquiry, content, work, confesses,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7784 0.1960 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7739 0.1929 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7203 0.1935 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7107 0.1921 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7363 0.1936 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7033 0.1931 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7200 0.1932 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7406 0.1921 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7082 0.1941 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6659 0.1960 sec/batch
# Nearest to they: messier, tyrrhenian, thawed, sextilis, disrupt, mcqueen, marathon, ibero,
# Nearest to by: places, manned, hosts, imposition, escalation, habsburg, cease, in,
# Nearest to that: conducts, maybe, independents, protectionism, encke, archaeologists, maverick, covenant,
# Nearest to a: restriction, once, concerts, sanders, tallest, guelleh, material, inadequate,
# Nearest to th: house, posteriori, devasting, uninterested, happiest, welcome, seven, chekhov,
# Nearest to he: heresies, boogie, tramiel, semitic, nepal, stoic, armpit, childhood,
# Nearest to as: flannel, tact, selene, rpm, playhouse, catechisms, echomail, severance,
# Nearest to also: behaviorism, creighton, igor, nes, usgs, luxuries, intensities, norah,
# Nearest to engine: oaths, scale, shocked, ngel, suburbs, smelting, pcm, firmness,
# Nearest to brother: preparatory, noble, plesiosaur, deception, dollywood, alarming, unforeseen, recherche,
# Nearest to square: overtime, walls, voucher, metropolitan, benefiting, lover, equator, heenan,
# Nearest to operations: pillow, piping, suppression, analyse, pollutants, funded, thackeray, druidism,
# Nearest to road: galatea, unter, domes, power, gordon, jessica, overcoming, aka,
# Nearest to san: eight, sepsis, adverbs, regan, everton, storefront, thereupon, passports,
# Nearest to experience: legally, jellinek, gregg, rory, hastings, computed, vulgate, massacres,
# Nearest to mathematics: mercury, vacuum, wrongly, work, booking, shivers, inquiry, diagonal,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6845 0.2012 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6557 0.2002 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6293 0.2008 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6120 0.2006 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6358 0.2001 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6401 0.2009 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5940 0.1441 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5644 0.2009 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4898 0.2002 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5023 0.2006 sec/batch
# Nearest to they: messier, tyrrhenian, sextilis, thawed, disrupt, place, mcqueen, marathon,
# Nearest to by: manned, places, imposition, cease, escalation, habsburg, reestablishment, cadences,
# Nearest to that: maybe, audacity, conducts, archaeologists, protectionism, deities, detriment, kata,
# Nearest to a: restriction, once, guelleh, concerts, sundial, manually, overdrive, antibiotics,
# Nearest to th: house, posteriori, devasting, lehi, uninterested, cymru, outlines, welcome,
# Nearest to he: heresies, boogie, tramiel, stoic, nepal, semitic, viceroy, his,
# Nearest to as: flannel, catechisms, tact, selene, playhouse, distinctively, unanimous, severance,
# Nearest to also: behaviorism, creighton, nes, norah, intensities, usgs, avoirdupois, perishes,
# Nearest to engine: oaths, ngel, scale, pcm, smelting, ericales, shocked, firmness,
# Nearest to brother: preparatory, noble, plesiosaur, recherche, children, macedonians, deception, alarming,
# Nearest to square: overtime, walls, benefiting, metropolitan, voucher, councilor, equator, belleville,
# Nearest to operations: pillow, pollutants, piping, suppression, elitist, analyse, druidism, funded,
# Nearest to road: galatea, unter, burrows, domes, mandinka, gordon, overcoming, aka,
# Nearest to san: eight, sepsis, regan, everton, anita, licensees, passports, bhaktivedanta,
# Nearest to experience: legally, jellinek, rory, vulgate, gregg, hastings, computed, tedious,
# Nearest to mathematics: mercury, vacuum, work, wrongly, shivers, diagonal, tallies, inquiry,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5135 0.2034 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5084 0.2008 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4743 0.2009 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5247 0.2004 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4938 0.2023 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4727 0.2036 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4398 0.2022 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3844 0.2030 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4126 0.2030 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4288 0.2000 sec/batch
# Nearest to they: thawed, messier, tyrrhenian, sextilis, disrupt, place, mcqueen, straight,
# Nearest to by: imposition, manned, escalation, cease, reestablishment, satisfy, egos, cadences,
# Nearest to that: maybe, detriment, conducts, audacity, deities, archaeologists, covenant, ganglia,
# Nearest to a: restriction, once, sundial, overdrive, guelleh, manually, element, material,
# Nearest to th: house, posteriori, devasting, lehi, electra, regnal, outlines, charterhouse,
# Nearest to he: heresies, boogie, tramiel, his, stoic, lerner, viceroy, semitic,
# Nearest to as: flannel, catechisms, tact, selene, severance, rpm, distinctively, usual,
# Nearest to also: behaviorism, creighton, nes, avoirdupois, usgs, norah, intensities, insurgents,
# Nearest to engine: pcm, ngel, smelting, scale, ericales, oaths, tubes, shocked,
# Nearest to brother: noble, preparatory, recherche, plesiosaur, children, worshipped, macedonians, dollywood,
# Nearest to square: metropolitan, overtime, equator, walls, benefiting, councilor, crooked, voucher,
# Nearest to operations: pillow, elitist, piping, suppression, pollutants, druidism, funded, numbers,
# Nearest to road: galatea, highways, mandinka, domes, aka, burrows, jessica, arizona,
# Nearest to san: eight, regan, sepsis, everton, anita, southerly, passports, bhaktivedanta,
# Nearest to experience: jellinek, legally, rory, vulgate, gregg, tedious, computed, negroponte,
# Nearest to mathematics: mercury, work, vacuum, wrongly, diagonal, content, shivers, inquiry,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4388 0.2033 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4094 0.2002 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4207 0.1941 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3965 0.1945 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4035 0.1942 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4464 0.1941 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3757 0.1948 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3733 0.1944 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4026 0.1946 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3625 0.1945 sec/batch
# Nearest to they: thawed, place, disrupt, sextilis, messier, undesirable, tyrrhenian, straight,
# Nearest to by: imposition, satisfy, in, cadences, reestablishment, escalation, fiasco, bitwise,
# Nearest to that: maybe, audacity, detriment, conducts, reality, strong, contractile, practicing,
# Nearest to a: restriction, once, sundial, overdrive, manually, guelleh, is, steric,
# Nearest to th: house, devasting, posteriori, happiest, regnal, charterhouse, lehi, galore,
# Nearest to he: heresies, boogie, tramiel, his, stoic, lerner, childhood, semitic,
# Nearest to as: flannel, catechisms, tact, severance, selene, distinctively, ramparts, extremist,
# Nearest to also: behaviorism, creighton, nes, avoirdupois, eroding, norah, spink, usgs,
# Nearest to engine: pcm, ericales, smelting, scale, ngel, tubes, shocked, reprogrammed,
# Nearest to brother: noble, preparatory, recherche, worshipped, was, condemned, children, elisabeth,
# Nearest to square: metropolitan, walls, equator, councilor, overtime, diagonal, belleville, heenan,
# Nearest to operations: pillow, piping, elitist, funded, intertwining, suppression, pollutants, pretensions,
# Nearest to road: galatea, highways, mandinka, arizona, domes, aka, pedestrian, somerset,
# Nearest to san: eight, regan, everton, sepsis, anita, passports, southerly, bhaktivedanta,
# Nearest to experience: jellinek, legally, rory, vulgate, tedious, computed, gregg, negroponte,
# Nearest to mathematics: work, mercury, vacuum, diagonal, wrongly, tallies, mathematical, fundamentally,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3665 0.1968 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3925 0.1948 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3659 0.1955 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3556 0.1945 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3727 0.1947 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3934 0.1953 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3801 0.1952 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3808 0.1949 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3049 0.1949 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3387 0.1946 sec/batch
# Nearest to they: disrupt, thawed, place, sextilis, undesirable, rbis, grammatically, messier,
# Nearest to by: imposition, in, satisfy, reestablishment, cease, cadences, the, hanja,
# Nearest to that: maybe, audacity, detriment, practicing, reality, nativity, kdf, encke,
# Nearest to a: restriction, once, sundial, safir, brillig, is, notting, overdrive,
# Nearest to th: devasting, posteriori, lehi, house, regnal, happiest, checkerboard, galore,
# Nearest to he: his, tramiel, heresies, boogie, stoic, lerner, successors, childhood,
# Nearest to as: flannel, catechisms, tact, distinctively, echomail, influx, extremist, ramparts,
# Nearest to also: behaviorism, creighton, avoirdupois, perishes, spink, nes, eroding, sendai,
# Nearest to engine: pcm, ericales, scale, smelting, reprogrammed, tubes, buyout, ngel,
# Nearest to brother: noble, deception, recherche, worshipped, preparatory, condemned, elisabeth, centaur,
# Nearest to square: metropolitan, equator, walls, diagonal, overtime, kilometers, councilor, packed,
# Nearest to operations: pillow, funded, elitist, numbers, lgm, piping, automated, units,
# Nearest to road: highways, mandinka, galatea, pedestrian, arizona, highway, aka, somerset,
# Nearest to san: everton, regan, sepsis, eight, anita, defences, bhaktivedanta, madagascar,
# Nearest to experience: jellinek, legally, rory, tedious, vulgate, computed, winding, hartley,
# Nearest to mathematics: work, mercury, mathematical, diagonal, vacuum, wrongly, tallies, fundamentally,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3156 0.1971 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2832 0.1957 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3552 0.1949 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3648 0.1944 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3958 0.1939 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2877 0.1981 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2751 0.1962 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3538 0.1940 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1971 0.1939 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3043 0.1956 sec/batch
# Nearest to they: thawed, disrupt, place, rbis, sextilis, marathon, messier, rog,
# Nearest to by: imposition, in, satisfy, the, cadences, cease, hanja, escalation,
# Nearest to that: maybe, audacity, reality, experiment, invincibility, detriment, axiom, nativity,
# Nearest to a: safir, notting, is, brillig, once, restriction, sundial, sanders,
# Nearest to th: posteriori, devasting, regnal, known, checkerboard, lehi, charterhouse, happiest,
# Nearest to he: his, tramiel, heresies, boogie, stoic, appalled, braintree, viceroy,
# Nearest to as: catechisms, flannel, tact, echomail, ramparts, distinctively, mamertines, severance,
# Nearest to also: behaviorism, spink, nes, insurgents, creighton, eroding, sendai, avoirdupois,
# Nearest to engine: pcm, ericales, tubes, smelting, reprogrammed, buyout, toy, scale,
# Nearest to brother: noble, deception, recherche, preparatory, condemned, worshipped, elisabeth, centaur,
# Nearest to square: metropolitan, equator, kilometers, walls, diagonal, feet, overtime, packed,
# Nearest to operations: funded, pillow, elitist, numbers, units, automated, lgm, sapir,
# Nearest to road: mandinka, galatea, pedestrian, highways, somerset, aka, arizona, highway,
# Nearest to san: everton, regan, sepsis, anita, bhaktivedanta, defences, eight, madagascar,
# Nearest to experience: jellinek, legally, rory, vulgate, gregg, tedious, negroponte, whitehouse,
# Nearest to mathematics: work, mathematical, mercury, diagonal, tallies, vacuum, unsympathetic, studied,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2854 0.1974 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3197 0.1951 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3475 0.0871 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2710 0.1955 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2465 0.1941 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1926 0.1941 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2263 0.1938 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2013 0.1939 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2051 0.1934 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1724 0.1928 sec/batch
# Nearest to they: disrupt, thawed, sextilis, reload, rbis, marathon, just, hair,
# Nearest to by: imposition, the, in, cadences, satisfy, cease, escalation, reestablishment,
# Nearest to that: maybe, reality, invincibility, audacity, advancements, warn, kdf, find,
# Nearest to a: is, notting, sanders, once, manually, restriction, brillig, safir,
# Nearest to th: regnal, posteriori, known, devasting, charterhouse, checkerboard, lehi, galore,
# Nearest to he: his, tramiel, heresies, stoic, viceroy, braintree, boogie, successors,
# Nearest to as: catechisms, flannel, distinctively, ramparts, homiletical, selene, belongings, extremist,
# Nearest to also: spink, behaviorism, nes, eroding, avoirdupois, sendai, creighton, perishes,
# Nearest to engine: pcm, buyout, ericales, reprogrammed, tubes, smelting, powered, toy,
# Nearest to brother: noble, deception, recherche, worshipped, elisabeth, preparatory, condemned, was,
# Nearest to square: metropolitan, walls, kilometers, equator, diagonal, feet, crooked, opened,
# Nearest to operations: numbers, lgm, pillow, automated, funded, units, elitist, pretensions,
# Nearest to road: mandinka, galatea, pedestrian, highways, highway, expressways, arizona, domes,
# Nearest to san: everton, sepsis, regan, defences, bhaktivedanta, anita, soliah, madagascar,
# Nearest to experience: jellinek, legally, rory, exile, negroponte, vulgate, ascetic, finds,
# Nearest to mathematics: mathematical, work, mercury, diagonal, tallies, studied, zetalisp, protoscience,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2740 0.1959 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2472 0.1930 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2245 0.1934 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1335 0.1938 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1677 0.1936 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2004 0.1930 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1587 0.1925 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1970 0.1930 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1951 0.1938 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1828 0.1931 sec/batch
# Nearest to they: disrupt, thawed, reload, place, marathon, just, rbis, sextilis,
# Nearest to by: imposition, satisfy, the, in, escalation, cadences, cease, hanja,
# Nearest to that: maybe, humanity, invincibility, reality, find, axiom, contractile, moves,
# Nearest to a: is, restriction, notting, sanders, sundial, manually, safir, affine,
# Nearest to th: posteriori, regnal, devasting, charterhouse, checkerboard, ae, galore, century,
# Nearest to he: his, tramiel, boogie, heresies, stoic, lerner, appalled, braintree,
# Nearest to as: catechisms, flannel, lcd, belongings, ramparts, set, extremist, homiletical,
# Nearest to also: spink, behaviorism, nes, creighton, perishes, sendai, eroding, norah,
# Nearest to engine: reprogrammed, pcm, ericales, buyout, tubes, lever, smelting, airframe,
# Nearest to brother: noble, deception, recherche, worshipped, centaur, dollywood, elisabeth, preparatory,
# Nearest to square: diagonal, metropolitan, walls, feet, kilometers, equator, opened, councilor,
# Nearest to operations: numbers, funded, units, automated, elitist, lgm, masculism, hsbc,
# Nearest to road: pedestrian, galatea, highways, touring, mandinka, highway, expressways, somerset,
# Nearest to san: everton, regan, sepsis, defences, madagascar, harbour, bhaktivedanta, soliah,
# Nearest to experience: jellinek, legally, negroponte, tedious, ascetic, exile, strive, rory,
# Nearest to mathematics: mathematical, work, mercury, diagonal, boole, studied, unsympathetic, tallies,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1475 0.1953 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2160 0.1927 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1702 0.1964 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1392 0.1931 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1720 0.1925 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1729 0.1924 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2061 0.1923 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1692 0.1908 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1698 0.1916 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1935 0.1912 sec/batch
# Nearest to they: disrupt, thawed, reload, marathon, place, rbis, hair, grammatically,
# Nearest to by: in, the, satisfy, imposition, cadences, hanja, cease, liquid,
# Nearest to that: maybe, humanity, reality, find, invincibility, meteoroid, axiom, moves,
# Nearest to a: is, notting, brillig, safir, least, restriction, once, unique,
# Nearest to th: regnal, devasting, posteriori, century, ae, checkerboard, charterhouse, galore,
# Nearest to he: his, tramiel, heresies, boogie, extroverted, appalled, stoic, childhood,
# Nearest to as: catechisms, flannel, set, contraceptive, disallowing, distinctively, extremist, belongings,
# Nearest to also: behaviorism, spink, nes, sendai, creighton, eroding, perishes, norah,
# Nearest to engine: reprogrammed, pcm, buyout, ericales, lever, turbofan, oaths, airframe,
# Nearest to brother: noble, deception, recherche, worshipped, centaur, preparatory, dollywood, camilla,
# Nearest to square: diagonal, metropolitan, walls, equator, kilometers, councilor, dimensional, feet,
# Nearest to operations: numbers, funded, units, elitist, automated, operation, hsbc, lgm,
# Nearest to road: pedestrian, mandinka, highways, highway, galatea, touring, expressways, somerset,
# Nearest to san: everton, regan, defences, sepsis, bhaktivedanta, harbour, anita, madagascar,
# Nearest to experience: jellinek, legally, negroponte, ascetic, exile, tedious, strive, haine,
# Nearest to mathematics: mathematical, work, mercury, diagonal, boole, tallies, gottlob, studied,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2030 0.1937 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1645 0.1923 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1600 0.1917 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1985 0.1919 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1437 0.1921 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1297 0.1914 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1584 0.1925 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1264 0.1932 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1856 0.1932 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1816 0.1927 sec/batch
# Nearest to they: thawed, marathon, disrupt, reload, rbis, place, grammatically, sextilis,
# Nearest to by: the, in, imposition, satisfy, hanja, coup, constitutional, al,
# Nearest to that: reality, maybe, humanity, invincibility, find, warn, audacity, moves,
# Nearest to a: notting, is, safir, once, to, harbinger, sanders, acquit,
# Nearest to th: regnal, century, devasting, posteriori, ae, charterhouse, checkerboard, ninth,
# Nearest to he: his, tramiel, was, appalled, braintree, stoic, viceroy, heresies,
# Nearest to as: catechisms, flannel, set, of, belongings, mamertines, extremist, distinctively,
# Nearest to also: spink, behaviorism, creighton, nes, igor, sendai, eroding, norah,
# Nearest to engine: reprogrammed, turbofan, pcm, buyout, lever, ericales, airframe, oaths,
# Nearest to brother: noble, deception, recherche, was, centaur, elisabeth, germanicus, preparatory,
# Nearest to square: metropolitan, kilometers, diagonal, equator, crooked, feet, ashmore, councilor,
# Nearest to operations: numbers, units, funded, operation, elitist, automated, hsbc, sapir,
# Nearest to road: pedestrian, mandinka, touring, highway, highways, galatea, expressways, somerset,
# Nearest to san: everton, regan, bhaktivedanta, defences, anita, sepsis, soliah, madagascar,
# Nearest to experience: jellinek, legally, exile, negroponte, strive, rory, catchphrases, ascetic,
# Nearest to mathematics: mathematical, mercury, work, gottlob, diagonal, tallies, boole, llb,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2493 0.2009 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1305 0.1975 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1624 0.1938 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1587 0.1936 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0316 0.1948 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1494 0.1950 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1646 0.1945 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1405 0.1944 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1703 0.0314 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1214 0.1941 sec/batch
# Nearest to they: disrupt, reload, thawed, marathon, rbis, sextilis, malignancies, just,
# Nearest to by: the, in, satisfy, imposition, hanja, cadences, escalation, eroding,
# Nearest to that: reality, moves, invincibility, would, meteoroid, maybe, satisfactorily, warn,
# Nearest to a: is, manually, once, notting, safir, nickname, acquit, brillig,
# Nearest to th: century, regnal, posteriori, devasting, ae, charterhouse, checkerboard, known,
# Nearest to he: his, tramiel, heresies, appalled, stoic, braintree, viceroy, was,
# Nearest to as: catechisms, flannel, set, of, lcd, distinctively, belongings, contraceptive,
# Nearest to also: spink, nes, behaviorism, for, sendai, eroding, creighton, or,
# Nearest to engine: reprogrammed, turbofan, pcm, lever, buyout, oaths, ericales, ignite,
# Nearest to brother: deception, noble, recherche, centaur, elisabeth, germanicus, dollywood, preparatory,
# Nearest to square: diagonal, metropolitan, walls, kilometers, opened, crooked, ashmore, taka,
# Nearest to operations: numbers, operation, units, funded, elitist, automated, lgm, hsbc,
# Nearest to road: pedestrian, mandinka, touring, highway, highways, galatea, chine, expressways,
# Nearest to san: everton, regan, soliah, anita, bhaktivedanta, defences, sepsis, sniping,
# Nearest to experience: jellinek, legally, strive, negroponte, catchphrases, haine, rory, tedious,
# Nearest to mathematics: mathematical, mercury, work, diagonal, gottlob, zetalisp, unsympathetic, boole,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0621 0.1974 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0691 0.1953 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0962 0.1945 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0382 0.1943 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0840 0.1942 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0382 0.1972 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0843 0.1953 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1001 0.1918 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0842 0.1915 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0557 0.1913 sec/batch
# Nearest to they: disrupt, reload, thawed, marathon, malignancies, rbis, sextilis, just,
# Nearest to by: the, in, imposition, satisfy, down, cadences, hanja, escalation,
# Nearest to that: invincibility, humanity, reality, moves, meteoroid, warn, would, maybe,
# Nearest to a: is, once, bottom, an, to, unique, manually, restriction,
# Nearest to th: century, regnal, devasting, posteriori, ae, charterhouse, acoustics, rd,
# Nearest to he: his, tramiel, appalled, braintree, heresies, viceroy, stoic, maher,
# Nearest to as: catechisms, of, set, indigenous, belongings, lcd, flannel, homiletical,
# Nearest to also: spink, behaviorism, nes, the, or, for, sendai, brazilians,
# Nearest to engine: reprogrammed, turbofan, buyout, lever, oaths, airframe, pcm, hp,
# Nearest to brother: noble, deception, recherche, centaur, dollywood, germanicus, was, overthrown,
# Nearest to square: diagonal, metropolitan, opened, walls, kilometers, ashmore, taka, crooked,
# Nearest to operations: numbers, operation, elitist, lgm, units, funded, automated, avis,
# Nearest to road: pedestrian, touring, mandinka, highway, galatea, highways, expressways, hub,
# Nearest to san: everton, regan, soliah, riordan, diego, sepsis, bhaktivedanta, defences,
# Nearest to experience: legally, jellinek, strive, negroponte, ascetic, exile, haine, tedious,
# Nearest to mathematics: mathematical, mercury, diagonal, gottlob, work, zetalisp, boole, tallies,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0197 0.1946 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0245 0.1921 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0072 0.1910 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0557 0.1913 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0696 0.1919 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0630 0.1916 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0732 0.1922 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0854 0.1923 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0526 0.1924 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0338 0.1925 sec/batch
# Nearest to they: marathon, disrupt, thawed, reload, malignancies, gentle, handicaps, place,
# Nearest to by: the, in, satisfy, imposition, cadences, hanja, mulroney, vox,
# Nearest to that: humanity, reality, meteoroid, invincibility, warn, axiom, aquatic, find,
# Nearest to a: is, unique, an, to, once, notting, of, sanders,
# Nearest to th: century, regnal, posteriori, ae, devasting, rd, acoustics, satyendra,
# Nearest to he: his, tramiel, appalled, braintree, maher, childhood, extroverted, boogie,
# Nearest to as: catechisms, set, of, lcd, homiletical, belongings, osh, distinctively,
# Nearest to also: spink, for, nes, behaviorism, the, links, or, psychological,
# Nearest to engine: reprogrammed, turbofan, buyout, oaths, pcm, engines, ignite, lever,
# Nearest to brother: noble, recherche, deception, centaur, germanicus, scattering, camilla, smash,
# Nearest to square: diagonal, dimensional, metropolitan, opened, walls, taka, ashmore, crooked,
# Nearest to operations: numbers, operation, elitist, multiplications, avis, funded, lgm, cisc,
# Nearest to road: pedestrian, touring, highway, highways, mandinka, galatea, expressways, hub,
# Nearest to san: regan, everton, sniping, soliah, riordan, diego, bhaktivedanta, anita,
# Nearest to experience: legally, jellinek, strive, negroponte, catchphrases, picirilli, haine, stimulating,
# Nearest to mathematics: mathematical, mercury, diagonal, gottlob, work, boole, zetalisp, tallies,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0346 0.1937 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0976 0.1927 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0718 0.1938 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0555 0.1923 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0554 0.1928 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0692 0.1928 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0769 0.1927 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0799 0.1926 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0822 0.1938 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0743 0.1945 sec/batch
# Nearest to they: disrupt, marathon, thawed, reload, gentle, malignancies, place, handicaps,
# Nearest to by: the, in, imposition, satisfy, hanja, cease, escalation, traitors,
# Nearest to that: humanity, reality, invincibility, meteoroid, moves, audacity, find, maybe,
# Nearest to a: is, of, once, an, sick, to, notting, theodorus,
# Nearest to th: century, regnal, devasting, ae, posteriori, charterhouse, rd, checkerboard,
# Nearest to he: his, tramiel, braintree, maher, pupil, stoic, appalled, heresies,
# Nearest to as: catechisms, of, the, set, oath, indigenous, homiletical, pashtunistan,
# Nearest to also: spink, for, nes, links, behaviorism, or, creighton, sendai,
# Nearest to engine: reprogrammed, oaths, turbofan, buyout, pcm, ignite, prostitutes, engines,
# Nearest to brother: noble, deception, recherche, germanicus, centaur, scattering, elisabeth, was,
# Nearest to square: diagonal, opened, metropolitan, taka, dimensional, kilometers, ashmore, walls,
# Nearest to operations: numbers, operation, elitist, avis, multiplications, funded, automated, lgm,
# Nearest to road: pedestrian, highway, mandinka, touring, highways, galatea, expressways, hub,
# Nearest to san: regan, everton, sniping, soliah, iniquity, bhaktivedanta, hegelians, anita,
# Nearest to experience: legally, jellinek, catchphrases, strive, impressionist, whitehouse, picirilli, negroponte,
# Nearest to mathematics: mathematical, mercury, gottlob, diagonal, work, boole, zetalisp, tallies,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0479 0.1972 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9958 0.1966 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0407 0.1981 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0583 0.2018 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0612 0.2042 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1081 0.2045 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1177 0.2046 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0329 0.2044 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0284 0.2037 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0567 0.2030 sec/batch
# Nearest to they: marathon, disrupt, reload, thawed, gentle, rbis, gss, granada,
# Nearest to by: the, in, satisfy, imposition, cadences, down, hanja, escalation,
# Nearest to that: reality, meteoroid, invincibility, moves, would, audacity, warn, experiment,
# Nearest to a: is, an, to, once, on, sanders, safir, notting,
# Nearest to th: century, regnal, devasting, ae, posteriori, charterhouse, rd, harpercollins,
# Nearest to he: his, tramiel, braintree, stoic, pupil, appalled, exeter, maher,
# Nearest to as: catechisms, of, set, indigenous, homiletical, lcd, tact, disallowing,
# Nearest to also: spink, nes, for, behaviorism, creighton, or, eroding, gnomes,
# Nearest to engine: turbofan, reprogrammed, oaths, engines, ignite, buyout, airframe, pcm,
# Nearest to brother: deception, noble, recherche, germanicus, was, centaur, elisabeth, perfectionism,
# Nearest to square: diagonal, taka, metropolitan, opened, kilometers, dimensional, ashmore, walls,
# Nearest to operations: operation, numbers, elitist, avis, lgm, funded, automated, monitors,
# Nearest to road: pedestrian, touring, mandinka, highway, galatea, highways, expressways, hub,
# Nearest to san: regan, everton, iniquity, soliah, sniping, bhaktivedanta, riordan, endorsing,
# Nearest to experience: legally, jellinek, catchphrases, strive, impressionist, whitehouse, haine, rory,
# Nearest to mathematics: mathematical, mercury, gottlob, diagonal, work, studied, boole, unsympathetic,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0127 0.2059 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0227 0.2041 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0306 0.2040 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0447 0.2053 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0793 0.2026 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0398 0.1802 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0008 0.2047 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9745 0.2052 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0093 0.2062 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9861 0.2059 sec/batch
# Nearest to they: marathon, disrupt, reload, thawed, gentle, rbis, granada, hostile,
# Nearest to by: the, in, imposition, cadences, hanja, satisfy, down, cease,
# Nearest to that: would, reality, warn, humanity, invincibility, torments, moves, meteoroid,
# Nearest to a: is, an, once, to, and, in, on, of,
# Nearest to th: century, regnal, rd, devasting, charterhouse, posteriori, ae, harpercollins,
# Nearest to he: his, pupil, braintree, was, stoic, viceroy, tramiel, appalled,
# Nearest to as: catechisms, of, the, oath, indigenous, set, sejong, apple,
# Nearest to also: spink, links, for, nes, the, eroding, behaviorism, creighton,
# Nearest to engine: turbofan, reprogrammed, oaths, engines, buyout, airframe, ignite, pcm,
# Nearest to brother: noble, deception, recherche, germanicus, was, elisabeth, centaur, ora,
# Nearest to square: diagonal, opened, taka, dimensional, walls, ashmore, metropolitan, crooked,
# Nearest to operations: numbers, operation, elitist, avis, lgm, multiplications, monitors, funded,
# Nearest to road: pedestrian, touring, highway, mandinka, galatea, highways, expressways, interstate,
# Nearest to san: regan, everton, soliah, sniping, iniquity, riordan, bhaktivedanta, diego,
# Nearest to experience: legally, jellinek, catchphrases, strive, ascetic, whitehouse, exile, haine,
# Nearest to mathematics: mathematical, mercury, diagonal, gottlob, work, studied, tallies, unsympathetic,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9950 0.2075 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9533 0.2049 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0078 0.2047 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0339 0.2052 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0112 0.2046 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0010 0.2050 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9131 0.2055 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9765 0.2049 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9116 0.2046 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9560 0.2052 sec/batch
# Nearest to they: disrupt, marathon, reload, thawed, rbis, just, malignancies, gentle,
# Nearest to by: the, in, imposition, satisfy, down, cadences, hanja, eroding,
# Nearest to that: would, torments, invincibility, humanity, reality, warn, meteoroid, moves,
# Nearest to a: is, an, and, to, of, on, in, the,
# Nearest to th: century, rd, regnal, devasting, posteriori, ae, charterhouse, acoustics,
# Nearest to he: his, pupil, braintree, tramiel, viceroy, stoic, exeter, appalled,
# Nearest to as: catechisms, of, indigenous, the, oath, set, lcd, vandals,
# Nearest to also: the, for, links, spink, nes, creighton, eroding, dion,
# Nearest to engine: turbofan, reprogrammed, oaths, engines, buyout, airframe, pcm, prostitutes,
# Nearest to brother: noble, recherche, deception, germanicus, centaur, father, mohammad, overthrown,
# Nearest to square: diagonal, taka, opened, dimensional, metropolitan, walls, crooked, ashmore,
# Nearest to operations: numbers, operation, elitist, avis, multiplications, lgm, funded, automated,
# Nearest to road: pedestrian, touring, mandinka, highway, galatea, highways, interstate, expressways,
# Nearest to san: regan, everton, diego, soliah, sniping, iniquity, riordan, bhaktivedanta,
# Nearest to experience: legally, jellinek, catchphrases, strive, exoplanets, ascetic, haine, negroponte,
# Nearest to mathematics: mathematical, mercury, gottlob, diagonal, work, studied, boole, fundamentally,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9916 0.2087 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0167 0.2084 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9608 0.2065 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9968 0.2060 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0185 0.2054 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9654 0.2047 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0135 0.2043 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9956 0.2040 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9668 0.2052 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9931 0.2103 sec/batch
# Nearest to they: disrupt, marathon, thawed, gentle, malignancies, just, reload, rbis,
# Nearest to by: the, in, satisfy, cadences, imposition, hanja, mulroney, vox,
# Nearest to that: would, reality, torments, invincibility, humanity, meteoroid, warn, will,
# Nearest to a: is, an, to, of, and, on, in, once,
# Nearest to th: century, regnal, rd, posteriori, devasting, ae, sneeze, charterhouse,
# Nearest to he: his, pupil, tramiel, fraternity, extroverted, braintree, viceroy, stoic,
# Nearest to as: catechisms, of, oath, the, lcd, more, disallowing, set,
# Nearest to also: for, the, links, nes, creighton, gnomes, episteme, or,
# Nearest to engine: oaths, reprogrammed, turbofan, engines, pcm, prostitutes, buyout, firmness,
# Nearest to brother: noble, recherche, deception, centaur, germanicus, father, overthrown, mohammad,
# Nearest to square: diagonal, opened, taka, dimensional, ashmore, crooked, heenan, prod,
# Nearest to operations: operation, numbers, elitist, multiplications, avis, lgm, funded, monitors,
# Nearest to road: pedestrian, touring, highway, mandinka, galatea, highways, interstate, expressways,
# Nearest to san: regan, sniping, everton, diego, iniquity, luca, soliah, anita,
# Nearest to experience: legally, catchphrases, jellinek, exoplanets, negroponte, robotic, haine, impressionist,
# Nearest to mathematics: mathematical, diagonal, mercury, gottlob, work, studied, bonn, emeritus,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0070 0.2112 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9871 0.2069 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9803 0.2063 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9893 0.2047 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0135 0.2046 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0005 0.2047 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9741 0.2044 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9485 0.2054 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9741 0.2049 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0282 0.2070 sec/batch
# Nearest to they: marathon, disrupt, gentle, reload, taxes, just, thawed, rog,
# Nearest to by: the, in, imposition, hanja, down, eroding, satisfy, cease,
# Nearest to that: invincibility, would, reality, meteoroid, moves, torments, warn, humanity,
# Nearest to a: is, an, of, to, in, on, and, once,
# Nearest to th: century, devasting, regnal, rd, posteriori, ae, nineteenth, influence,
# Nearest to he: his, pupil, tramiel, viceroy, braintree, fraternity, exeter, extroverted,
# Nearest to as: of, the, catechisms, indigenous, oath, more, lcd, other,
# Nearest to also: for, the, links, creighton, nes, diwali, or, behaviorism,
# Nearest to engine: turbofan, reprogrammed, oaths, engines, prostitutes, pcm, buyout, fuel,
# Nearest to brother: recherche, deception, noble, centaur, germanicus, elisabeth, mohammad, father,
# Nearest to square: diagonal, opened, taka, metropolitan, kilometers, dimensional, crooked, prod,
# Nearest to operations: operation, numbers, avis, elitist, multiplications, lgm, funded, monitors,
# Nearest to road: pedestrian, touring, highway, mandinka, highways, interstate, galatea, expressways,
# Nearest to san: regan, sniping, diego, everton, luca, iniquity, soliah, anita,
# Nearest to experience: legally, jellinek, catchphrases, impressionist, donnelly, picirilli, negroponte, strive,
# Nearest to mathematics: mathematical, diagonal, mercury, gottlob, work, bonn, studied, mathematik,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9875 0.2089 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0661 0.2047 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0423 0.2055 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0475 0.2047 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8492 0.1951 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8941 0.1958 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8063 0.1946 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8686 0.1947 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9127 0.1954 sec/batch
# Nearest to they: their, able, themselves, more, them, some, marathon, division,
# Nearest to by: the, in, for, a, of, also, and, such,
# Nearest to that: the, not, and, would, however, dominos, although, have,
# Nearest to a: in, is, the, an, of, and, for, to,
# Nearest to th: century, rd, playoffs, posteriori, devasting, nineteenth, seven, fifteenth,
# Nearest to he: his, him, tramiel, viceroy, worked, was, exclaimed, fraternity,
# Nearest to as: of, the, and, or, to, other, is, in,
# Nearest to also: for, the, in, is, links, by, a, of,
# Nearest to engine: turbofan, engines, oaths, reprogrammed, prostitutes, funny, fuel, ratios,
# Nearest to brother: younger, perfectionism, mohammad, recherche, father, death, oba, rumpus,
# Nearest to square: diagonal, opened, parish, bongos, councilor, grid, taka, dimensional,
# Nearest to operations: operation, numbers, avis, transformative, binary, multiplications, decimal, funded,
# Nearest to road: touring, route, pedestrian, highway, mandinka, expressways, flashback, highways,
# Nearest to san: francisco, sniping, diego, regan, luca, jose, iniquity, endorsing,
# Nearest to experience: legally, mind, neurobiology, communicating, valvular, intercept, meteorological, impressionist,
# Nearest to mathematics: mathematical, bonn, diagonal, work, studied, emeritus, mathematik, heinemann,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8167 0.1973 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8791 0.1943 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8541 0.1953 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8381 0.1951 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8664 0.1945 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8670 0.1949 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8602 0.1954 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8632 0.1958 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8458 0.1951 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8391 0.1957 sec/batch
# Nearest to they: themselves, their, them, able, taxes, marathon, call, some,
# Nearest to by: the, in, a, of, for, and, also, its,
# Nearest to that: the, not, would, there, torments, exists, all, centralisation,
# Nearest to a: in, an, the, of, is, and, on, to,
# Nearest to th: century, rd, playoffs, posteriori, devasting, nineteenth, fifteenth, seven,
# Nearest to he: his, him, studied, viceroy, graduated, worked, met, spent,
# Nearest to as: of, the, and, other, or, is, in, which,
# Nearest to also: for, the, in, links, is, by, called, of,
# Nearest to engine: turbofan, oaths, engines, reprogrammed, prostitutes, funny, erroneous, mirrored,
# Nearest to brother: younger, perfectionism, mohammad, death, father, recherche, rumpus, oba,
# Nearest to square: diagonal, opened, bongos, taka, parish, councilor, grid, guglielmo,
# Nearest to operations: numbers, operation, avis, transformative, multiplications, binary, algeria, decimal,
# Nearest to road: pedestrian, route, touring, highway, expressways, mandinka, flashback, crossing,
# Nearest to san: francisco, sniping, diego, luca, regan, jose, endorsing, iniquity,
# Nearest to experience: legally, mind, intercept, impressionist, meteorological, neurobiology, feelings, communicating,
# Nearest to mathematics: bonn, mathematical, diagonal, work, studied, emeritus, masters, mathematik,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8513 0.1973 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8504 0.1951 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8109 0.1949 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8284 0.1947 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8844 0.1956 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8519 0.1965 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9598 0.1953 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8958 0.1949 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9428 0.1947 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8436 0.1947 sec/batch
# Nearest to they: themselves, taxes, their, able, them, some, scythians, call,
# Nearest to by: the, in, of, a, for, one, also, and,
# Nearest to that: the, not, would, and, later, signed, there, centralisation,
# Nearest to a: in, the, an, is, of, on, and, for,
# Nearest to th: century, rd, devasting, posteriori, nineteenth, playoffs, fifteenth, seven,
# Nearest to he: his, him, worked, studied, met, graduated, viceroy, was,
# Nearest to as: of, the, and, other, or, in, which, is,
# Nearest to also: for, the, in, links, is, by, called, of,
# Nearest to engine: turbofan, engines, oaths, reprogrammed, prostitutes, ratios, jumo, funny,
# Nearest to brother: younger, perfectionism, mohammad, recherche, death, children, rumpus, oba,
# Nearest to square: diagonal, opened, parish, bongos, councilor, taka, guglielmo, kilometers,
# Nearest to operations: operation, numbers, avis, binary, assisting, transformative, algeria, ricimer,
# Nearest to road: pedestrian, expressways, highway, mandinka, touring, route, flashback, deeds,
# Nearest to san: francisco, sniping, diego, regan, luca, iniquity, jose, endorsing,
# Nearest to experience: mind, impressionist, legally, neurobiology, meteorological, strive, intercept, feelings,
# Nearest to mathematics: mathematical, bonn, diagonal, studied, work, mathematik, masters, heinemann,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7849 0.1957 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8853 0.1947 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7794 0.1965 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9087 0.1952 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8353 0.1951 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8558 0.1954 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9174 0.0943 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8191 0.1978 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8172 0.2001 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8587 0.1965 sec/batch
# Nearest to they: their, themselves, them, able, scythians, some, halides, division,
# Nearest to by: the, in, a, of, for, and, also, which,
# Nearest to that: not, would, the, however, later, be, and, to,
# Nearest to a: in, an, is, the, and, of, for, on,
# Nearest to th: century, rd, playoffs, posteriori, nineteenth, devasting, fifteenth, lesions,
# Nearest to he: his, him, was, viceroy, studied, met, worked, pupil,
# Nearest to as: of, the, and, to, other, is, a, in,
# Nearest to also: for, the, links, in, is, by, see, called,
# Nearest to engine: turbofan, engines, oaths, reprogrammed, prostitutes, jumo, underpowered, dickens,
# Nearest to brother: younger, perfectionism, death, mohammad, father, children, recherche, son,
# Nearest to square: diagonal, opened, parish, bongos, grid, feet, taka, notting,
# Nearest to operations: numbers, operation, avis, binary, multiplications, transformative, varieties, algeria,
# Nearest to road: pedestrian, route, highway, touring, expressways, mandinka, deeds, interstate,
# Nearest to san: francisco, diego, sniping, luca, regan, jose, pm, endorsing,
# Nearest to experience: mind, meteorological, legally, neurobiology, impressionist, strive, ascetic, weishaupt,
# Nearest to mathematics: mathematical, bonn, diagonal, studied, work, masters, heinemann, quaestor,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8145 0.1969 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8433 0.1956 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8449 0.1946 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7849 0.1945 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8598 0.1955 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8438 0.1948 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8584 0.1953 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7680 0.1953 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8035 0.1952 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7983 0.1945 sec/batch
# Nearest to they: their, them, themselves, able, some, taxes, halides, division,
# Nearest to by: the, a, in, for, of, and, also, one,
# Nearest to that: not, the, would, and, is, be, to, however,
# Nearest to a: is, in, the, an, of, and, by, for,
# Nearest to th: century, rd, posteriori, nineteenth, playoffs, devasting, lesions, fifteenth,
# Nearest to he: his, him, tramiel, studied, viceroy, worked, spent, met,
# Nearest to as: of, the, and, other, is, to, which, in,
# Nearest to also: for, the, in, is, links, by, of, see,
# Nearest to engine: turbofan, oaths, engines, reprogrammed, prostitutes, jumo, funny, underpowered,
# Nearest to brother: younger, perfectionism, mohammad, recherche, father, oba, rumpus, death,
# Nearest to square: diagonal, opened, parish, grid, feet, bongos, councilor, taka,
# Nearest to operations: numbers, operation, avis, binary, algeria, exponentiation, transformative, multiplications,
# Nearest to road: route, pedestrian, highway, expressways, touring, highways, mandinka, roads,
# Nearest to san: francisco, diego, jose, sniping, regan, california, luca, pm,
# Nearest to experience: mind, meteorological, legally, neurobiology, ascetic, intercept, impressionist, strive,
# Nearest to mathematics: mathematical, bonn, diagonal, studied, work, masters, quaestor, heinemann,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7447 0.1970 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7960 0.1951 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8605 0.1960 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8223 0.1967 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8169 0.1967 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8675 0.1983 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8521 0.1962 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8207 0.1957 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8264 0.1961 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8456 0.1966 sec/batch
# Nearest to they: their, themselves, them, some, able, do, have, call,
# Nearest to by: the, a, in, for, and, of, also, which,
# Nearest to that: not, the, would, although, and, is, to, however,
# Nearest to a: in, the, is, an, of, and, for, by,
# Nearest to th: century, rd, posteriori, playoffs, nineteenth, devasting, fifteenth, seven,
# Nearest to he: his, him, studied, tramiel, viceroy, worked, met, graduated,
# Nearest to as: of, the, other, and, which, in, to, for,
# Nearest to also: for, the, in, is, links, by, and, called,
# Nearest to engine: turbofan, engines, oaths, reprogrammed, prostitutes, funny, jumo, dickens,
# Nearest to brother: younger, father, perfectionism, son, rumpus, recherche, death, mohammad,
# Nearest to square: diagonal, opened, councilor, grid, parish, bongos, guglielmo, prod,
# Nearest to operations: operation, numbers, avis, binary, transformative, multiplications, algeria, amalgamation,
# Nearest to road: route, pedestrian, expressways, highway, mandinka, crossing, himachal, roads,
# Nearest to san: francisco, diego, regan, sniping, jose, california, pm, luca,
# Nearest to experience: mind, neurobiology, meteorological, communicating, intercept, legally, strive, geodesy,
# Nearest to mathematics: bonn, mathematical, studied, diagonal, work, masters, medals, exams,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9060 0.1989 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8274 0.1954 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8248 0.1987 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8388 0.1973 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8626 0.1971 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8550 0.1979 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8407 0.1990 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8666 0.1980 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8254 0.1977 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7918 0.1960 sec/batch
# Nearest to they: them, their, themselves, some, do, able, have, taxes,
# Nearest to by: the, in, a, of, and, for, which, also,
# Nearest to that: not, the, is, and, by, to, although, would,
# Nearest to a: in, is, the, of, an, for, on, and,
# Nearest to th: century, rd, nineteenth, posteriori, seven, devasting, playoffs, fifteenth,
# Nearest to he: his, him, studied, viceroy, spent, tramiel, worked, met,
# Nearest to as: of, the, and, other, which, in, for, to,
# Nearest to also: for, in, the, is, links, of, and, by,
# Nearest to engine: turbofan, engines, oaths, reprogrammed, dickens, prostitutes, jumo, hints,
# Nearest to brother: younger, perfectionism, father, rumpus, recherche, son, cousins, death,
# Nearest to square: diagonal, opened, councilor, parish, bongos, per, guglielmo, grid,
# Nearest to operations: operation, numbers, avis, binary, multiplications, transformative, algeria, decimal,
# Nearest to road: highway, expressways, route, pedestrian, mandinka, highways, deeds, roads,
# Nearest to san: diego, francisco, sniping, regan, luca, jose, pm, endorsing,
# Nearest to experience: mind, neurobiology, communicating, meteorological, intercept, lucid, impressionist, legally,
# Nearest to mathematics: bonn, mathematical, diagonal, studied, work, masters, exams, medals,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8624 0.1993 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8372 0.1988 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8971 0.1979 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9167 0.1976 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9108 0.1961 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8550 0.1977 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7892 0.1963 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8316 0.1968 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7576 0.1971 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8487 0.1974 sec/batch
# Nearest to they: themselves, them, do, able, their, some, convolution, fannish,
# Nearest to by: the, in, a, of, and, for, also, which,
# Nearest to that: not, the, and, by, however, would, all, to,
# Nearest to a: in, the, is, an, of, on, and, by,
# Nearest to th: century, rd, posteriori, nineteenth, devasting, seven, playoffs, origins,
# Nearest to he: his, him, met, studied, worked, exclaimed, viceroy, fraternity,
# Nearest to as: of, the, and, for, in, other, which, a,
# Nearest to also: for, the, links, in, is, and, of, by,
# Nearest to engine: engines, turbofan, reprogrammed, oaths, dickens, prostitutes, hints, jumo,
# Nearest to brother: younger, perfectionism, recherche, rumpus, mohammad, death, father, rastislav,
# Nearest to square: diagonal, opened, parish, councilor, feet, per, bongos, grid,
# Nearest to operations: operation, numbers, avis, binary, multiplications, decimal, algeria, transformative,
# Nearest to road: expressways, highway, mandinka, pedestrian, route, deeds, flashback, lennox,
# Nearest to san: diego, francisco, sniping, regan, jose, luca, pm, california,
# Nearest to experience: mind, neurobiology, meteorological, lucid, communicating, exoplanets, intercept, ascetic,
# Nearest to mathematics: bonn, mathematical, diagonal, studied, masters, work, interrelationships, exams,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8299 0.1991 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8158 0.1968 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
    # 500个最常用的词
